# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
salary = pd.read_excel('data/adult.data.xlsx')
salary.head(2)
# Out:
#    age           job type     id      degree  yrs employed  \
# 0   39          State-gov  77516   Bachelors            13
# 1   50   Self-emp-not-inc  83311   Bachelors            13
#
#         married status        spouse job        fam stat    race gender  col1  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male  2174
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male     0
#
#    col2  col3         country sal range
# 0     0    40   United-States     <=50K
# 1     0    13   United-States     <=50K

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   job type        32561 non-null  object
#  2   id              32561 non-null  int64
#  3   degree          32561 non-null  object
#  4   yrs employed    32561 non-null  int64
#  5   married status  32561 non-null  object
#  6   spouse job      32561 non-null  object
#  7   fam stat        32561 non-null  object
#  8   race            32561 non-null  object
#  9   gender          32561 non-null  object
#  10  col1            32561 non-null  int64
#  11  col2            32561 non-null  int64
#  12  col3            32561 non-null  int64
#  13  country         32561 non-null  object
#  14  sal range       32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
sns.displot(salary, x='yrs employed', col='sal range', binwidth=1)

# %%
sns.displot(salary, x='age', col='sal range')

# %%
sns.displot(salary, x='degree', col='sal range').set_xticklabels(rotation=45)

# %%
sns.displot(salary, x='married status', col='sal range').set_xticklabels(rotation=45)

# %%
sns.displot(salary, x='fam stat', col='sal range').set_xticklabels(rotation=45)

# %%
sns.displot(salary, x='race', col='sal range').set_xticklabels(rotation=45)

# %%
sns.displot(salary, x='gender', col='sal range').set_xticklabels(rotation=45)

# %%
salary.groupby('sal range').mean()[['age', 'yrs employed']]
# Out:
# /var/folders/_l/2tlwk9553fg0v8q_1rnmz_mr0000gn/T/ipykernel_95667/2642269867.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   salary.groupby('sal range').mean()[['age', 'yrs employed']]
#                  age  yrs employed
# sal range
#  <=50K     36.783738      9.595065
#  >50K      44.249841     11.611657

# %%
salary.groupby('married status').mean()[['age', 'yrs employed']]
# Out:
# /var/folders/_l/2tlwk9553fg0v8q_1rnmz_mr0000gn/T/ipykernel_95667/967753822.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   salary.groupby('married status').mean()[['age', 'yrs employed']]
#                               age  yrs employed
# married status
#  Divorced               43.041639     10.030385
#  Married-AF-spouse      32.478261     10.173913
#  Married-civ-spouse     43.247596     10.320646
#  Married-spouse-absent  40.578947      9.308612
#  Never-married          28.150988      9.962464
#  Separated              39.354146      9.293659
#  Widowed                58.975831      9.093656
